# %%
# 교보문고 웹페이지에서 신상품 정보를 크롤링하는 코드를 구현

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from urllib.request import urlopen

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# 교보문고 신상 웹페이지
driver.get("https://product.kyobobook.co.kr/new/KOR")
bsObject = BeautifulSoup(driver.page_source, 'html.parser')

# 책의 상세 웹페이지 주소를 추출하여 리스트에 저장
book_page_urls = []
items = bsObject.find_all('a', class_='prod_link')
for item in items:
    url = item.select_one('div.prod_area.horizontal > a')
    print(url)
    book_page_urls.append(url)

# 웹페이지로부터 필요한 정보를 추출합니다.
for index, book_page_url in enumerate(book_page_urls):
    title = bsObject.find('span', class_='prod_title')
    author = bsObject.find('h3', class_='title_heading')
    price = bsObject.find('span', class_='org_price')

    print(f"책 제목: {title}")
    print(f"저자: {author}")
    print(f"가격: {price}")
    print()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None
#
# 책 제목: None
# 저자: None
# 가격: None

# %%
 ol > li:nth-child(1) > div.prod_area.horizontal > div.prod_thumb_box.size_lg > a
